# %%
mydata = read.csv("C:/Users/Bagli/Google Drive/QT_L123_NOxPTS_v2.csv")

# %%
summary(mydata)
# Out:
#        Q1                T1              Q2              T2
#  Min.   :    1.7   Min.   :  0.1   Min.   : 1304   Min.   :  4.0
#  1st Qu.:51354.2   1st Qu.:131.4   1st Qu.:58011   1st Qu.:126.4
#  Median :54354.8   Median :135.1   Median :60205   Median :128.9
#  Mean   :54026.5   Mean   :124.8   Mean   :60289   Mean   :125.3
#  3rd Qu.:56931.2   3rd Qu.:139.1   3rd Qu.:63615   3rd Qu.:132.6
#  Max.   :83155.6   Max.   :154.2   Max.   :85764   Max.   :158.5
#  NA's   :383       NA's   :9       NA's   :41      NA's   :11
#        Q3               T3             NOx1             PTS1
#  Min.   : 39646   Min.   : 10.1   Min.   :0.0000   Min.   :0.000000
#  1st Qu.:163443   1st Qu.:136.9   1st Qu.:0.2904   1st Qu.:0.002819
#  Median :182736   Median :141.4   Median :0.3716   Median :0.004144
#  Mean   :160517   Mean   :120.4   Mean   :0.3534   Mean   :0.006060
#  3rd Qu.:188026   3rd Qu.:144.4   3rd Qu.:0.4460   3rd Qu.:0.006270
# ...

# %%
print("Q1")
quantile(mydata$Q1,na.rm=TRUE)
print("Q2")
quantile(mydata$Q2,na.rm=TRUE)
print("Q3")
quantile(mydata$Q3,na.rm=TRUE)
print("T1")
quantile(mydata$T1,na.rm=TRUE)
print("T2")
quantile(mydata$T2,na.rm=TRUE)
print("T3")
quantile(mydata$T3,na.rm=TRUE)
print("NOx1")
quantile(mydata$NOx1,na.rm=TRUE)
print("NOx2")
quantile(mydata$NOx2,na.rm=TRUE)
print("NOx3")
quantile(mydata$NOx3,na.rm=TRUE)
print("PTS1")
quantile(mydata$PTS1,na.rm=TRUE)
print("PTS2")
quantile(mydata$PTS2,na.rm=TRUE)
print("PTS3")
quantile(mydata$PTS3,na.rm=TRUE)
# Out:
# [1] "Q1"
#      0%     25%     50%     75%    100%
#     1.7 51354.2 54354.8 56931.2 83155.6
# [1] "Q2"
#       0%      25%      50%      75%     100%
#  1303.90 58011.30 60205.00 63615.45 85764.00
# [1] "Q3"
#       0%      25%      50%      75%     100%
#  39645.5 163442.8 182735.8 188025.9 213143.8
# [1] "T1"
#    0%   25%   50%   75%  100%
#   0.1 131.4 135.1 139.1 154.2
# [1] "T2"
#    0%   25%   50%   75%  100%
#   4.0 126.4 128.9 132.6 158.5
# [1] "T3"
#    0%   25%   50%   75%  100%
#  10.1 136.9 141.4 144.4 168.1
# [1] "NOx1"
#        0%       25%       50%       75%      100%
# 0.0000000 0.2903593 0.3716416 0.4460401 1.1255041
# [1] "NOx2"
#        0%       25%       50%       75%      100%
# 0.0000000 0.4501958 0.5048197 0.5480838 1.3509345
# [1] "NOx3"
#         0%        25%        50%        75%       100%
# 0.02752378 1.06561493 1.49822098 1.61660023 4.84149019
# [1] "PTS1"
#          0%         25%         50%         75%        100%
# ...

# %%
boxplot(mydata$T1)
# Out:
# plot without title

# %%
boxplot(mydata$T2)
# Out:
# plot without title

# %%
boxplot(mydata$T3)
# Out:
# plot without title

# %%
boxplot(mydata$Q1)
# Out:
# plot without title

# %%
boxplot(mydata$Q2)
# Out:
# plot without title

# %%
boxplot(mydata$Q3)
# Out:
# plot without title

# %%
boxplot(mydata$NOx1)

# %%
boxplot(mydata$NOx2)

# %%
boxplot(mydata$NOx3)
# Out:
# plot without title

# %%
boxplot(mydata$PTS1)
# Out:
# plot without title

# %%
boxplot(mydata$PTS2)

# %%
boxplot(mydata$PTS3)

# %%
hist(mydata$Q1)
# Out:
# Plot with title “Histogram of mydata$Q1”

# %%
hist(mydata$Q2)
# Out:
# Plot with title “Histogram of mydata$Q2”

# %%
hist(mydata$Q3)
# Out:
# Plot with title “Histogram of mydata$Q3”

# %%
hist(mydata$T1)
# Out:
# Plot with title “Histogram of mydata$T1”

# %%
hist(mydata$T2)
# Out:
# Plot with title “Histogram of mydata$T2”

# %%
hist(mydata$T3)
# Out:
# Plot with title “Histogram of mydata$T3”

# %%
hist(mydata$NOx1)
# Out:
# Plot with title "Histogram of mydata$NOx1"

# %%
hist(mydata$NOx2)
# Out:
# Plot with title "Histogram of mydata$NOx2"

# %%
hist(mydata$NOx3)
# Out:
# Plot with title "Histogram of mydata$NOx3"

# %%
hist(mydata$PTS1)
# Out:
# Plot with title "Histogram of mydata$PTS1"

# %%
hist(mydata$PTS2)
# Out:
# Plot with title "Histogram of mydata$PTS2"

# %%
hist(mydata$PTS3)
# Out:
# Plot with title "Histogram of mydata$PTS3"
